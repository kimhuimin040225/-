# %% [markdown]
# <a href="https://colab.research.google.com/github/kimhuimin040225/-/blob/main/%5B%ED%95%B4%EC%82%AC%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%A7%88%EC%9D%B4%EB%8B%9D%5D_8%EB%B2%88%EC%A7%B8_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from scipy import stats
df = pd.read_csv("before_after_worktime.csv")
before = df["before_min"]
after = df["after_min"]
diff = before - after
result = stats.ttest_rel(before, after, alternative="greater")

print("평균 차이(before - after):", diff.mean())
print("t-statistic:", result.statistic)
print("p-value:", result.pvalue)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2038/595605788.py in <cell line: 0>()
#       1 import pandas as pd
#       2 from scipy import stats
# ----> 3 df = pd.read_csv("before_after_worktime.csv")
#       4 before = df["before_min"]
#       5 after = df["after_min"]
#
# ...
